# %% [markdown]
# # Import des modules requis

# %%
# %matplotlib inline
# !pip install tensorflow==2.11.0
# Out:
# Requirement already satisfied: tensorflow==2.11.0 in c:\users\miala\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow==2.11.0) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (15.0.6.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.11.0)
# Requirement already satisfied: packaging in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.19.6)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.7.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.21.5)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.30.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (4.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (63.4.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.51.1)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow==2.11.0) (23.1.21)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\miala\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\miala\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\miala\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\miala\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\miala\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\miala\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\miala\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\miala\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\miala\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\miala\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\miala\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\miala\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\miala\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow==2.11.0) (3.2.2)

# %%
import numpy as np                   
import matplotlib.pyplot as plt     
import random  
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import accuracy_score

# %% [markdown]
# # MNIST dataset

# %%
# The MNIST data is split between 60,000 28 x 28 pixel training images and 10,000 28 x 28 pixel images
mnist = tf.keras.datasets.mnist

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

print("X_train shape", X_train.shape)
print("y_train shape", Y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", Y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 7s 1us/step
# X_train shape (60000, 28, 28)
# y_train shape (60000,)
# X_test shape (10000, 28, 28)
# y_test shape (10000,)

# %% [markdown]
# # Data Visualization

# %%
plt.rcParams['figure.figsize'] = (9,9) 

random.seed(3)
nums = [random.randint(0, len(X_train)) for x in range(9)]

for i, num in enumerate(nums):
    plt.subplot(3,3,i+1)
    plt.imshow(X_train[num], cmap='gray', interpolation='none')
    plt.title("Class {}".format(Y_train[num]))
    
plt.tight_layout()

# %% [markdown]
# # Reformater l'input

# %%
print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)

# building the input vector from the 28x28 pixels
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalizing the data to help with the training
X_train /= 255
X_test /= 255

# print the final input shape ready for training
print("Train matrix shape", X_train.shape)
print("Test matrix shape", X_test.shape)
# Out:
# X_train shape (60000, 784)
# Y_train shape (60000,)
# X_test shape (10000, 784)
# Y_test shape (10000,)
# Train matrix shape (60000, 784)
# Test matrix shape (10000, 784)

# %%
# one-hot encoding 
n_classes = 10
print("Shape before one-hot encoding: ", Y_train.shape)
Y_train = np_utils.to_categorical(Y_train, n_classes)
Y_test = np_utils.to_categorical(Y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)

# %% [markdown]
# # Construisons un premier réseau

# %% [markdown]
# ## Import Keras Layers

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import Conv2D, Flatten, MaxPooling2D

# %% [markdown]
# ## Setting network parameters

# %%
model = Sequential()
model.add(Dense(512, input_shape=(784,)))
model.add(Activation('relu'))                            
model.add(Dropout(0.2))

model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(10))
model.add(Activation('softmax'))

# %% [markdown]
# ## Compiling and training the model:

# %%
# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# training the model and saving metrics in history
history = model.fit(X_train, Y_train,
          batch_size=128, epochs=20,
          verbose=2,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 469/469 - 9s - loss: 0.0451 - accuracy: 0.9860 - val_loss: 0.0673 - val_accuracy: 0.9788 - 9s/epoch - 20ms/step
# Epoch 2/20
# 469/469 - 9s - loss: 0.0428 - accuracy: 0.9858 - val_loss: 0.0668 - val_accuracy: 0.9792 - 9s/epoch - 19ms/step
# Epoch 3/20
# 469/469 - 9s - loss: 0.0404 - accuracy: 0.9871 - val_loss: 0.0650 - val_accuracy: 0.9796 - 9s/epoch - 20ms/step
# Epoch 4/20
# 469/469 - 9s - loss: 0.0381 - accuracy: 0.9882 - val_loss: 0.0646 - val_accuracy: 0.9800 - 9s/epoch - 19ms/step
# Epoch 5/20
# 469/469 - 9s - loss: 0.0348 - accuracy: 0.9887 - val_loss: 0.0622 - val_accuracy: 0.9803 - 9s/epoch - 20ms/step
# Epoch 6/20
# 469/469 - 9s - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.0660 - val_accuracy: 0.9800 - 9s/epoch - 19ms/step
# Epoch 7/20
# 469/469 - 9s - loss: 0.0331 - accuracy: 0.9896 - val_loss: 0.0642 - val_accuracy: 0.9809 - 9s/epoch - 19ms/step
# Epoch 8/20
# 469/469 - 9s - loss: 0.0297 - accuracy: 0.9904 - val_loss: 0.0656 - val_accuracy: 0.9803 - 9s/epoch - 20ms/step
# Epoch 9/20
# 469/469 - 9s - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.0628 - val_accuracy: 0.9804 - 9s/epoch - 20ms/step
# Epoch 10/20
# 469/469 - 9s - loss: 0.0280 - accuracy: 0.9910 - val_loss: 0.0606 - val_accuracy: 0.9813 - 9s/epoch - 20ms/step
# Epoch 11/20
# 469/469 - 9s - loss: 0.0250 - accuracy: 0.9918 - val_loss: 0.0626 - val_accuracy: 0.9811 - 9s/epoch - 20ms/step
# Epoch 12/20
# 469/469 - 9s - loss: 0.0245 - accuracy: 0.9919 - val_loss: 0.0616 - val_accuracy: 0.9805 - 9s/epoch - 20ms/step
# Epoch 13/20
# 469/469 - 9s - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.0744 - val_accuracy: 0.9776 - 9s/epoch - 20ms/step
# Epoch 14/20
# 469/469 - 9s - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.0681 - val_accuracy: 0.9803 - 9s/epoch - 20ms/step
# Epoch 15/20
# 469/469 - 9s - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0609 - val_accuracy: 0.9822 - 9s/epoch - 20ms/step
# Epoch 16/20
# 469/469 - 10s - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.0639 - val_accuracy: 0.9811 - 10s/epoch - 20ms/step
# Epoch 17/20
# 469/469 - 9s - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.0721 - val_accuracy: 0.9802 - 9s/epoch - 20ms/step
# Epoch 18/20
# 469/469 - 9s - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0672 - val_accuracy: 0.9815 - 9s/epoch - 20ms/step
# Epoch 19/20
# 469/469 - 9s - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.0632 - val_accuracy: 0.9833 - 9s/epoch - 20ms/step
# Epoch 20/20
# 469/469 - 9s - loss: 0.0182 - accuracy: 0.9939 - val_loss: 0.0684 - val_accuracy: 0.9811 - 9s/epoch - 20ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9256\1766539505.py in <module>
#       9 fig = plt.figure()
#      10 plt.subplot(2,1,1)
# ---> 11 plt.plot(history.history['acc'])
#      12 plt.plot(history.history['val_acc'])
#      13 plt.title('model accuracy')
#
# KeyError: 'acc'

# %%
# plotting the metrics
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

fig

# %% [markdown]
# ## Evaluate the model

# %%
score = model.evaluate(X_test, Y_test)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0684 - accuracy: 0.9811
# Test score: 0.06836450099945068
# Test accuracy: 0.9811000227928162

# %% [markdown]
# # Convolution

# %%
tf.keras.layers.Conv2D(32,                      # on crée 32 filtres
                       (3, 3),                  # kernel de taille (3,3)
                       input_shape=(28,28,1))

# %%
tf.keras.layers.MaxPooling2D(pool_size=(2,2))

# %%
# Recharger le dataset
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(60000, 28, 28, 1) # Ajouter une dimension supplémentaire pour représenter la couche unique
X_test = X_test.reshape(10000, 28, 28, 1)

X_train, X_test = X_train / 255.0, X_test / 255.0

print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)
# Out:
# Training matrix shape (60000, 28, 28, 1)
# Testing matrix shape (10000, 28, 28, 1)

# %%
                               
model = tf.keras.models.Sequential()                                 

model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(100, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(
    optimizer=optimizer, 
    loss="sparse_categorical_crossentropy", 
    metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 5408)              0
#
#  dense_16 (Dense)            (None, 100)               540900
#
#  dense_17 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 542,230
# Trainable params: 542,230
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train and test the model

# %%
model.fit(X_train, Y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2319 - accuracy: 0.9291
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0733 - accuracy: 0.9780
# Epoch 3/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0462 - accuracy: 0.9860
# Epoch 4/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0342 - accuracy: 0.9896
# Epoch 5/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0248 - accuracy: 0.9924
# Epoch 6/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0180 - accuracy: 0.9948
# Epoch 7/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 8/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0102 - accuracy: 0.9971
# Epoch 9/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0079 - accuracy: 0.9978
# Epoch 10/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0052 - accuracy: 0.9988

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
accuracy_score(Y_test, predictions)
# Out:
# 313/313 [==============================] - 2s 7ms/step
# 0.9883
